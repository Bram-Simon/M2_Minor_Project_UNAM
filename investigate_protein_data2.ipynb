# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Code Block 1

base_dir = ".."
output_dir = os.path.join(base_dir, "output")

data_dir = os.path.join(base_dir, "raw")
filename_acral_mex_tpms = "acral_mexican_cohort_tpms_primaries.csv"

df_mex_tpms = pd.read_csv (os.path.join(data_dir, filename_acral_mex_tpms))
display(df_mex_tpms)
# Out:
#        ENSEMBL_GENE_ID    PR40961a    PR40961d    PR40962a   PR40963a  \
# 0      ENSG00000000003   13.793976   17.755723   25.676495  12.026561
# 1      ENSG00000000005    0.000000    0.208321    0.718533   0.000000
# 2      ENSG00000000419  106.211668  120.324267  102.063161  60.327869
# 3      ENSG00000000457   26.501177   30.065128   23.353706   5.634242
# 4      ENSG00000000460   40.115216   46.228147   60.396665   8.809694
# ...                ...         ...         ...         ...        ...
# 60661  ENSG00000288695    0.000000    0.000000    0.000000   0.000000
# 60662  ENSG00000288696    0.000000    0.000000    0.000000   0.099204
# 60663  ENSG00000288697    0.000000    0.000000    0.000000   0.000000
# 60664  ENSG00000288698    0.000000    0.000000    0.000000   0.000000
# 60665  ENSG00000288699    0.000000    0.000000    0.000000   0.000000
#
#          PR40966a    PR40967a    PR40968a    PR40969a    PR40970a  ...  \
# ...

# %%
import mygene

# Initialize the MyGene object
mg = mygene.MyGeneInfo()

# List of Ensembl gene IDs
ensembl_ids = ["ENSG00000139618", "ENSG00000273279", "ENSG00000157764"]

# Query MyGene.info to get the gene names
gene_info = mg.querymany(ensembl_ids, scopes='ensembl.gene', fields='symbol', species='human')

# Print the results
for gene in gene_info:
    print(f"Ensembl ID: {gene['query']} -> Gene Name: {gene.get('symbol', 'Not found')}")
# Out:
# querying 1-3...done.
# Finished.
# 1 input query terms found no hit:
# 	['ENSG00000273279']
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Ensembl ID: ENSG00000139618 -> Gene Name: BRCA2
# Ensembl ID: ENSG00000273279 -> Gene Name: Not found
# Ensembl ID: ENSG00000157764 -> Gene Name: BRAF

# %%
from Ensembl_converter import EnsemblConverter

# Create an instance of EnsemblConverter
converter = EnsemblConverter()

# Provide a list of Ensembl IDs
ensembl_ids = ['ENSG00000000457', 'ENSG00000273486', 'ENSG00000273493']

# Convert Ensembl IDs to gene symbols
result = converter.convert_ids(ensembl_ids)

# Print the resulting DataFrame
print(result)
# Out:
#               ENSG           Symbol
# 0  ENSG00000000457            SCYL3
# 1  ENSG00000273486  ENSG00000273486
# 2  ENSG00000273493  ENSG00000273493

# %%
import mygene

# Initialize the MyGene object
mg = mygene.MyGeneInfo()

# Query MyGene.info to get the gene names
gene_info = mg.querymany(df_mex_tpms["ENSEMBL_GENE_ID"], scopes='ensembl.gene', fields='symbol', species='human')

# Create a dictionary to map ENSEMBL_GENE_ID to gene names
gene_name_dict = {gene['query']: gene.get('symbol', 'Not found') for gene in gene_info}

# Convert ENSEMBL_GENE_ID to gene names in the dataframe
df_mex_tpms_gene_names = df_mex_tpms.copy()
df_mex_tpms_gene_names["gene_name"] = df_mex_tpms_gene_names["ENSEMBL_GENE_ID"].map(gene_name_dict)
df_mex_tpms_gene_names.drop("ENSEMBL_GENE_ID", axis=1, inplace=True)

display(df_mex_tpms)
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 19001-20000...done.
# querying 20001-21000...done.
# querying 21001-22000...done.
# querying 22001-23000...done.
# querying 23001-24000...done.
# querying 24001-25000...done.
# querying 25001-26000...done.
# querying 26001-27000...done.
# querying 27001-28000...done.
# querying 28001-29000...done.
# querying 29001-30000...done.
# querying 30001-31000...done.
# querying 31001-32000...done.
# ...

# %%
# Get the column names of the DataFrame
col_names = df_mex_tpms_gene_names.columns.tolist()

# Move "gene_name" to the first position
col_names.insert(0, col_names.pop(col_names.index("gene_name")))

# Reindex the DataFrame with the new column order
df_mex_tpms_gene_names = df_mex_tpms_gene_names.reindex(columns=col_names)

# Display the updated DataFrame
display(df_mex_tpms_gene_names)
# Out:
#        gene_name    PR40961a    PR40961d    PR40962a   PR40963a    PR40966a  \
# 0         TSPAN6   13.793976   17.755723   25.676495  12.026561   10.860670
# 1           TNMD    0.000000    0.208321    0.718533   0.000000    0.296648
# 2           DPM1  106.211668  120.324267  102.063161  60.327869  139.884746
# 3          SCYL3   26.501177   30.065128   23.353706   5.634242   19.059267
# 4          FIRRM   40.115216   46.228147   60.396665   8.809694   12.476231
# ...          ...         ...         ...         ...        ...         ...
# 60661  Not found    0.000000    0.000000    0.000000   0.000000    0.000000
# 60662  Not found    0.000000    0.000000    0.000000   0.099204    0.000000
# 60663  Not found    0.000000    0.000000    0.000000   0.000000    0.000000
# 60664  Not found    0.000000    0.000000    0.000000   0.000000    0.000000
# 60665  Not found    0.000000    0.000000    0.000000   0.000000    0.000000
#
# ...

# %%
#genes_model = ["KRAS", "NRAS", "BRAF", "RRAS2", "HRAS", "MAP2K7", "MAP2K1", "MAP3K5", "MAP3K1", "MAP2K4", "MAPK1", "EPHB2"]
genes_model = ["MAP2K7", "MAP2K1", "MAP2K2", "KRAS", "HRAS", "NRAS", "BRAF", "ZHX2", "RAF1", "ARAF", "KRAF", "MAPK1", "MAPK3"]
#"AFP"?????? for Rafp??

#"Ras", "RAS", "ras", "Rasp", "RASp", "rasp", "Raf", "RAF", "raf", "Rafp", "RAFp", "rafp", "MEK", "MEKp", "MEKpp", "ERK", "ERKp", "ERKpp"] #, "Not found"]

# Filter the DataFrame to include only the genes in the model
df_mex_tpms_model = df_mex_tpms_gene_names[df_mex_tpms_gene_names["gene_name"].str.upper().isin([gene.upper() for gene in genes_model])]
0
display(df_mex_tpms_model)
# Out:
#       gene_name    PR40961a    PR40961d    PR40962a    PR40963a    PR40966a  \
# 1361     MAP2K7   33.613250   36.263508   45.401201   25.189022   40.644189
# 1405       ARAF   89.303398  102.395333   60.544801  103.275195  118.301665
# 2164      MAPK1  111.139773   93.798951   54.294605  144.660535   67.083347
# 2714      MAPK3   19.782848   26.843353   51.051772   90.544569   88.332321
# 5872     MAP2K2  106.541974  128.258793  161.651333  108.734476  129.415499
# 6538       RAF1  113.978064  115.243821  200.583017   80.802718  140.227993
# 6778       KRAS    9.687829    9.800682   12.448759    4.532392   11.520364
# 10127      BRAF   25.903370   25.852674   26.769931   16.763005   20.788376
# 12490    MAP2K1   31.719849   41.689981   16.632876   20.055204   37.285167
# 13740      HRAS   57.936554   27.179312   21.517903   65.850468  140.220353
# 14532      ZHX2   83.574459   80.010870   25.710910   42.896697   43.032957
# ...

# %%
group_1 = ['PR51978a',
'PR51948a',
'PR40984a',
'PR41905a',
'PR40966a',
'PR41916a',
'PR51951a',
'PR40963a',
'PR41929d',
'PR41045a',
'PR41030a']

group_2 = [
'PR41928d',
'PR51928a',
'PR41017a',
'PR41901a',
'PR40985a',
'PR41044a',
'PR51932a',
'PR41011a',
'PR41930d',
'PR41917a',
'PR40989a',
'PR41927d',
'PR40971a',
'PR40962a',
'PR40961a',
'PR41920a',
'PR40967a'
]

group_3 = [
'PR40996a',
'PR40994a',
'PR41020a',
'PR40997a',
'PR41921a',
'PR51979a',
'PR51956a',
'PR40968a',
'PR41002a',
'PR41913a',
'PR40969a',
'PR41025a',
'PR40988a',
'PR41035a',
'PR40970a',
'PR40990a',
'PR41023f',
'PR40986a',
'PR41912a'
]

# %%
import pandas as pd
from scipy.stats import f_oneway
import numpy as np

df_test_subset = df_mex_tpms_model['gene_name']# + df_mex_tpms_model[group_1]

display(df_test_subset)
# Out:
# 1361     MAP2K7
# 1405       ARAF
# 2164      MAPK1
# 2714      MAPK3
# 5872     MAP2K2
# 6538       RAF1
# 6778       KRAS
# 10127      BRAF
# 12490    MAP2K1
# 13740      HRAS
# 14532      ZHX2
# 22243      NRAS
# Name: gene_name, dtype: object

# %%
import pandas as pd
from scipy.stats import f_oneway
import numpy as np

def calculate_BH_adjusted_pvalues(df, p_value_col='p-value', FDR=0.05):
    """Applies the Benjamini-Hochberg procedure to adjust p-values
    
    df     :       DataFrame
        DataFrame containing the results
    p_value_col     :    String
        The name of the column containing p-values
    FDR:    :      int
        The false discovery rate (default: 0.05)
    """
    # Sort by p-value
    df = df.sort_values(p_value_col).reset_index(drop=True)
    
    # Calculate ranks
    df['rank'] = df.index + 1
    
    # Calculate BH critical values
    df['BH_critical_value'] = (df['rank'] / len(df)) * FDR
    
    # Adjusted p-values
    df['adjusted_p-value'] = df[p_value_col] * len(df) / df['rank']
    
    # Ensure adjusted p-values do not exceed 1
    df['adjusted_p-value'] = df['adjusted_p-value'].clip(upper=1.0)
    
    return df

# Initialize a list to hold ANOVA results
anova_results = []

N_tests = 0

# Perform ANOVA for each gene across the tumor sample groups
for gene in df_mex_tpms_model['gene_name']:
    # Extract gene expression data for the current gene across all samples
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)
    
    # Group the expression data based on the defined sample groups
    group_1_data = gene_expression[group_1].values.flatten()
    group_2_data = gene_expression[group_2].values.flatten()
    group_3_data = gene_expression[group_3].values.flatten()
    
    # Perform ANOVA if all groups have data
    if len(group_1_data) > 1 and len(group_2_data) > 1 and len(group_3_data) > 1:
        f_stat, p_val = f_oneway(group_1_data, group_2_data, group_3_data)
        anova_results.append({'Gene': gene, 'F-statistic': f_stat, 'p-value': p_val})
        N_tests += 1
    else:
        anova_results.append({'Gene': gene, 'F-statistic': np.nan, 'p-value': np.nan})

print("We performed {} statistical tests".format(N_tests))    

# Convert results to a DataFrame
df_anova = pd.DataFrame(anova_results)

# Apply the Benjamini-Hochberg procedure
df_anova = calculate_BH_adjusted_pvalues(df_anova)

# Display the results with adjusted p-values
display(df_anova)

for gene in df_mex_tpms_model['gene_name']:
    # Extract gene expression data for the current gene across all samples
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)

#df_significant_only = df_anova.copy()

for adj_pval in df_anova['adjusted_p-value']:
    df_significant_only = df_anova[df_anova['adjusted_p-value']<=0.05]#.drop('adjusted_p-value', axis=1)
#df_significant_only['adjusted_p-value' >= 0.05].drop
display(df_significant_only)
# Out:
# We performed 12 statistical tests
#       Gene  F-statistic   p-value  rank  BH_critical_value  adjusted_p-value
# 0    MAPK3     8.438126  0.000791     1           0.004167          0.009490
# 1   MAP2K2     6.287333  0.003965     2           0.008333          0.023792
# 2     ZHX2     5.716584  0.006209     3           0.012500          0.024836
# 3     HRAS     4.848372  0.012506     4           0.016667          0.037517
# 4    MAPK1     2.649300  0.081959     5           0.020833          0.196702
# 5     KRAS     0.953001  0.393397     6           0.025000          0.786793
# 6     NRAS     0.707470  0.498410     7           0.029167          0.854417
# 7     ARAF     0.574030  0.567412     8           0.033333          0.851118
# 8     BRAF     0.388149  0.680611     9           0.037500          0.907481
# 9   MAP2K1     0.361038  0.698998    10           0.041667          0.838797
# 10  MAP2K7     0.299784  0.742480    11           0.045833          0.809978
# ...

# %%
df_mex_tpms_model
# Out:
#       gene_name    PR40961a    PR40961d    PR40962a    PR40963a    PR40966a  \
# 1361     MAP2K7   33.613250   36.263508   45.401201   25.189022   40.644189
# 1405       ARAF   89.303398  102.395333   60.544801  103.275195  118.301665
# 2164      MAPK1  111.139773   93.798951   54.294605  144.660535   67.083347
# 2714      MAPK3   19.782848   26.843353   51.051772   90.544569   88.332321
# 5872     MAP2K2  106.541974  128.258793  161.651333  108.734476  129.415499
# 6538       RAF1  113.978064  115.243821  200.583017   80.802718  140.227993
# 6778       KRAS    9.687829    9.800682   12.448759    4.532392   11.520364
# 10127      BRAF   25.903370   25.852674   26.769931   16.763005   20.788376
# 12490    MAP2K1   31.719849   41.689981   16.632876   20.055204   37.285167
# 13740      HRAS   57.936554   27.179312   21.517903   65.850468  140.220353
# 14532      ZHX2   83.574459   80.010870   25.710910   42.896697   43.032957
# ...

# %%
df_transposed = df_mex_tpms_model.transpose()
df_transposed.columns = df_transposed.iloc[0]
df_transposed['group'] = 0

df_transposed.index.name = 'sample'
display(df_transposed)

for sample in df_transposed.index:
    if sample in group_1:
        df_transposed.at[sample, 'group'] = 1
    elif sample in group_2:
        df_transposed.at[sample, 'group'] = 2
    elif sample in group_3:
        df_transposed.at[sample, 'group'] = 3
    #else:

df_samples_without_group = df_transposed.copy()
df_samples_without_group = df_samples_without_group[df_samples_without_group['group'].isin([0])]

display(df_samples_without_group)

df_transposed = df_transposed[df_transposed['group'].isin([1, 2, 3])]

#for sample in df_transposed.index:
#    if 

display(df_transposed)
# Out:
# gene_name     MAP2K7        ARAF       MAPK1      MAPK3      MAP2K2  \
# sample
# gene_name     MAP2K7        ARAF       MAPK1      MAPK3      MAP2K2
# PR40961a    33.61325   89.303398  111.139773  19.782848  106.541974
# PR40961d   36.263508  102.395333   93.798951  26.843353  128.258793
# PR40962a   45.401201   60.544801   54.294605  51.051772  161.651333
# PR40963a   25.189022  103.275195  144.660535  90.544569  108.734476
# ...              ...         ...         ...        ...         ...
# PR51979a   26.796289  110.593246   80.259564  35.434049  330.813801
# PR51984a   40.081814  104.964939   57.128712  88.736857  120.934212
# PR51985a   27.333211  113.928656   76.085204  56.708567  102.306025
# PR52000a   48.256597  197.957983   35.118244  31.794762   132.71366
# PR52006a    36.94417  132.032639   61.455192  77.158248   86.451318
#
# gene_name        RAF1       KRAS       BRAF     MAP2K1        HRAS  \
# sample
# ...

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.11.2

# %%
import seaborn as sns
from statannotations.Annotator import Annotator
from itertools import combinations

output_dir_boxplots = os.path.join(output_dir, "boxplots_MAPK_genes")

df_with_groups = df_transposed.copy()

relevant_genes = df_with_groups.columns.drop('group')

df_with_groups['group'] = df_with_groups['group'].astype(str)

groups = ["1", "2", "3"]

for gene in relevant_genes:
    print("Investigating statistical differences between different groups for gene: {}".format(gene))
    
    df_temp = df_with_groups.copy()

    all_cols = set(df_temp.columns)
    cols_to_keep = {gene, 'group'}
    cols_to_drop = list(all_cols - cols_to_keep)
    df_temp = df_temp.drop(columns=cols_to_drop)

    #grouped = df_temp.groupby(by = 'group')
    #display(grouped.mean())

    # Ensure the data is numeric
    df_temp[gene] = pd.to_numeric(df_temp[gene], errors='coerce')

    # Drop any rows with NaNs in the gene column
    df_temp = df_temp.dropna(subset=[gene])

    x = 'group'
    y = gene
    
    #ax = sns.boxplot(data = df_temp, x=x, y=y, order=groups)
    #plt.figure()
    #plt.plot()

    pairs = list(combinations(groups, r=2))
    pairs

    ax2 = sns.boxplot(data = df_temp, x=x, y=y, order=groups)
    annotator = Annotator(ax2, pairs, data = df_temp, x=x, y=y, order=groups)
    annotator.new_plot(ax2, pairs, data = df_temp, x=x, y=y, order=groups)
    annotator.configure(test="Mann-Whitney", comparisons_correction="Bonferroni", verbose=2)
    test_results = annotator.apply_test().annotate()

    #annotator.configure(test="Mann-Whitney")

    #_, test_results = annot.annotate()

    #for res in test_results: print(res.data)

    title_size = 22
    label_size = 16

    #annotator.apply_and_annotate()
    ax2.set_title("{}".format(gene), fontsize= title_size)
    ax2.set_xlabel("Group", fontsize=label_size)
    ax2.set_ylabel("Normalized expression", fontsize=label_size)
    
    plt.savefig(os.path.join(output_dir_boxplots, "boxplot_{}.png".format(gene)))
    plt.figure()
    plt.show()
    
    #plt.close()
# Out:
# Investigating statistical differences between different groups for gene: MAP2K7
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# 1 vs. 2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=9.100e+01
# 2 vs. 3: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.470e+02
# 1 vs. 3: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=8.400e+01
# Investigating statistical differences between different groups for gene: ARAF
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# 1 vs. 2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.022e-01 U_stat=7.100e+01
# ...

# %%
import seaborn as sns
from statannotations.Annotator import Annotator
from itertools import combinations

pairs = list(combinations(groups, r=2))
pairs

# %%
from statannotations.Annotator import Annotator
import seaborn as sns

# Perform ANOVA for each gene across the tumor sample groups
for gene in df_mex_tpms_model['gene_name']:
    # Extract gene expression data for the current gene across all samples
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)
    
    # Group the expression data based on the defined sample groups
    group_1_data = gene_expression[group_1].values.flatten()
    group_2_data = gene_expression[group_2].values.flatten()
    group_3_data = gene_expression[group_3].values.flatten()

ax = sns.boxplot(data = df_mex_tpms_model, x = )

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `significant_genes` and `df_mex_tpms_model` are already defined

# List of significant genes
significant_gene_names = significant_genes['Gene'].tolist()

# Loop through each significant gene and create a box plot
for gene in significant_gene_names:
    # Extract the expression data for the current gene
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)
    
    # Create a DataFrame suitable for seaborn
    plot_data = pd.DataFrame({
        'Expression': gene_expression[group_1].values.flatten().tolist() + 
                      gene_expression[group_2].values.flatten().tolist() + 
                      gene_expression[group_3].values.flatten().tolist(),
        'Group': ['Group 1'] * len(group_1) + ['Group 2'] * len(group_2) + ['Group 3'] * len(group_3)
    })
    
    # Plot using seaborn
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Group', y='Expression', data=plot_data)
    plt.title(f'Expression of {gene} across Groups')
    plt.xlabel('Group')
    plt.ylabel('Expression Level')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `significant_genes` and `df_mex_tpms_model` are already defined

# List of significant genes
significant_gene_names = significant_genes['Gene'].tolist()

# Loop through each significant gene and create a box plot
for gene in significant_gene_names:
    # Extract the expression data for the current gene
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)
    
    # Create a DataFrame suitable for seaborn
    plot_data = pd.DataFrame({
        'Expression': gene_expression[group_1].values.flatten().tolist() + 
                      gene_expression[group_2].values.flatten().tolist() + 
                      gene_expression[group_3].values.flatten().tolist(),
        'Group': ['Group 1'] * len(group_1) + ['Group 2'] * len(group_2) + ['Group 3'] * len(group_3)
    })
    
    # Plot using seaborn
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Group', y='Expression', data=plot_data)
    plt.title(f'Expression of {gene} across Groups')
    plt.xlabel('Group')
    plt.ylabel('Expression Level')
    plt.show()


from statannotations.Annotator import Annotator

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator

# Assuming `significant_genes` and `df_mex_tpms_model` are already defined

# List of significant genes
significant_gene_names = significant_genes['Gene'].tolist()

# Define the pairs of groups to compare
pairs = [('Group 1', 'Group 2'), ('Group 1', 'Group 3'), ('Group 2', 'Group 3')]

# Loop through each significant gene and create a box plot with annotations
for gene in significant_gene_names:
    # Extract the expression data for the current gene
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)

    # Create a DataFrame suitable for seaborn
    plot_data = pd.DataFrame({
        'Expression': gene_expression[group_1].values.flatten().tolist() + 
                      gene_expression[group_2].values.flatten().tolist() + 
                      gene_expression[group_3].values.flatten().tolist(),
        'Group': ['Group 1'] * len(group_1) + ['Group 2'] * len(group_2) + ['Group 3'] * len(group_3)
    })

    # Plot using seaborn
    plt.figure(figsize=(8, 6))
    ax = sns.boxplot(x='Group', y='Expression', data=plot_data)
    plt.title(f'Expression of {gene} across Groups')
    plt.xlabel('Group')
    plt.ylabel('Expression Level')

    # Add statistical annotations using statannotations
    annotator = Annotator(ax, pairs, data=plot_data, x='Group', y='Expression')
    annotator.configure(test='t-test_ind', text_format='star', loc='inside', verbose=2)
    annotator.apply_and_annotate()

    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg

# Assuming `significant_genes` and `df_mex_tpms_model` are already defined

# List of significant genes
significant_gene_names = significant_genes['Gene'].tolist()

# Define the pairs of groups to compare
pairs = [('Group 1', 'Group 2'), ('Group 1', 'Group 3'), ('Group 2', 'Group 3')]

# Loop through each significant gene and create a box plot with annotations
for gene in significant_gene_names:
    # Extract the expression data for the current gene
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)

    # Create a DataFrame suitable for seaborn
    plot_data = pd.DataFrame({
        'Expression': gene_expression[group_1].values.flatten().tolist() + 
                      gene_expression[group_2].values.flatten().tolist() + 
                      gene_expression[group_3].values.flatten().tolist(),
        'Group': ['Group 1'] * len(group_1) + ['Group 2'] * len(group_2) + ['Group 3'] * len(group_3)
    })

    # Plot using seaborn
    plt.figure(figsize=(8, 6))
    ax = sns.boxplot(x='Group', y='Expression', data=plot_data)
    plt.title(f'Expression of {gene} across Groups')
    plt.xlabel('Group')
    plt.ylabel('Expression Level')

    # Perform pairwise comparisons using pingouin
    pairwise_results = pg.pairwise_ttests(dv='Expression', between='Group', data=plot_data, padjust='bonf')
    
    for i, (group1, group2) in enumerate(pairs):
        p_value = pairwise_results.query(f'A == "{group1}" and B == "{group2}"')['p-unc'].values[0]
        if p_value < 0.001:
            annotation = '***'
        elif p_value < 0.01:
            annotation = '**'
        elif p_value < 0.05:
            annotation = '*'
        else:
            annotation = 'ns'
        
        # Calculate the y position for the line and text
        y_max = plot_data['Expression'].max()
        y, h, col = y_max + 10, 10, 'k'
        
        # Adding the comparison line between the boxes
        x1, x2 = i, i + 1
        ax.plot([x1, x1, x2, x2], [y, y + h, y + h, y], lw=1.5, c=col)
        ax.text((x1 + x2) * .5, y + h, annotation, ha='center', va='bottom', color=col, fontsize=12)
    
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg

# Assuming `significant_genes` and `df_mex_tpms_model` are already defined

# List of significant genes
significant_gene_names = significant_genes['Gene'].tolist()

# Define the pairs of groups to compare
pairs = [('Group 1', 'Group 2'), ('Group 1', 'Group 3'), ('Group 2', 'Group 3')]

# Loop through each significant gene and create a box plot with annotations
for gene in significant_gene_names:
    # Extract the expression data for the current gene
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)

    # Create a DataFrame suitable for seaborn
    plot_data = pd.DataFrame({
        'Expression': gene_expression[group_1].values.flatten().tolist() + 
                      gene_expression[group_2].values.flatten().tolist() + 
                      gene_expression[group_3].values.flatten().tolist(),
        'Group': ['Group 1'] * len(group_1) + ['Group 2'] * len(group_2) + ['Group 3'] * len(group_3)
    })

    # Plot using seaborn
    plt.figure(figsize=(8, 6))
    ax = sns.boxplot(x='Group', y='Expression', data=plot_data)
    plt.title(f'Expression of {gene} across Groups')
    plt.xlabel('Group')
    plt.ylabel('Expression Level')

    # Perform pairwise comparisons using pingouin
    pairwise_results = pg.pairwise_ttests(dv='Expression', between='Group', data=plot_data, padjust='bonf')
    
    # Annotate the plot manually
    for i, (group1, group2) in enumerate(pairs):
        p_value = pairwise_results.query(f'A == "{group1}" and B == "{group2}"')['p-unc'].values[0]
        if p_value < 0.001:
            annotation = '***'
        elif p_value < 0.01:
            annotation = '**'
        elif p_value < 0.05:
            annotation = '*'
        else:
            annotation = 'ns'
        
        # Adjust the y position for the line and text
        y_max = plot_data['Expression'].max()
        y, h, col = y_max + (10 * (i + 1)), 10, 'k'
        
        # Adding the comparison line between the boxes
        x1, x2 = i, i + 1
        ax.plot([x1, x1, x2, x2], [y, y + h, y + h, y], lw=1.5, c=col)
        ax.text((x1 + x2) * .5, y + h, annotation, ha='center', va='bottom', color=col, fontsize=12)

    plt.ylim(0, y + 2 * h)  # Adjust the y-limits to accommodate the annotations
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg

# Assuming `significant_genes` and `df_mex_tpms_model` are already defined

# List of significant genes
significant_gene_names = significant_genes['Gene'].tolist()

# Define the pairs of groups to compare
pairs = [('Group 1', 'Group 2'), ('Group 2', 'Group 3'), ('Group 1', 'Group 3')]

# Loop through each significant gene and create a box plot with annotations
for gene in significant_gene_names:
    # Extract the expression data for the current gene
    gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1)

    # Create a DataFrame suitable for seaborn
    plot_data = pd.DataFrame({
        'Expression': gene_expression[group_1].values.flatten().tolist() + 
                      gene_expression[group_2].values.flatten().tolist() + 
                      gene_expression[group_3].values.flatten().tolist(),
        'Group': ['Group 1'] * len(group_1) + ['Group 2'] * len(group_2) + ['Group 3'] * len(group_3)
    })

    # Plot using seaborn
    plt.figure(figsize=(8, 6))
    ax = sns.boxplot(x='Group', y='Expression', data=plot_data)
    plt.title(f'Expression of {gene} across Groups')
    plt.xlabel('Group')
    plt.ylabel('Expression Level')

    # Perform pairwise comparisons using pingouin
    pairwise_results = pg.pairwise_ttests(dv='Expression', between='Group', data=plot_data, padjust='bonf')
    
    # Annotate the plot manually with correct layering
    y_max = plot_data['Expression'].max()
    h_step = 10  # Step height between lines
    
    for i, (group1, group2) in enumerate(pairs):
        p_value = pairwise_results.query(f'A == "{group1}" and B == "{group2}"')['p-unc'].values[0]
        if p_value < 0.001:
            annotation = '***'
        elif p_value < 0.01:
            annotation = '**'
        elif p_value < 0.05:
            annotation = '*'
        else:
            annotation = 'ns'
        
        # Calculate height based on distance between groups
        if group1 == 'Group 1' and group2 == 'Group 3':
            y = y_max + 2 * h_step  # Highest line
        elif group1 == 'Group 2' and group2 == 'Group 3':
            y = y_max + h_step  # Middle line
        else:
            y = y_max  # Lowest line
        
        h = 5  # Height of the vertical line segments
        col = 'k'  # Color of the lines and text
        
        x1 = pairs.index((group1, group2))  # Get the x-position based on the pair
        x2 = x1 + 1
        ax.plot([x1, x1, x2, x2], [y, y + h, y + h, y], lw=1.5, c=col)
        ax.text((x1 + x2) * .5, y + h, annotation, ha='center', va='bottom', color=col, fontsize=12)

    plt.ylim(0, y_max + 3 * h_step)  # Adjust the y-limits to accommodate the annotations
    plt.show()

# %%
import pandas as pd
from scipy.stats import f_oneway

# Create a dictionary to hold groups
groups = {'Group 1': group_1, 'Group 2': group_2, 'Group 3': group_3}

# Initialize a list to hold ANOVA results
anova_results = []

# Perform ANOVA for each gene across the groups
for gene in df_mex_tpms_model['gene_name']:
    group_data = []
    for group_name, group_genes in groups.items():
        gene_expression = df_mex_tpms_model[df_mex_tpms_model['gene_name'] == gene].drop("gene_name", axis=1).values.flatten()
        group_data.append(gene_expression)
    f_stat, p_val = f_oneway(*group_data)
    anova_results.append({'Gene': gene, 'F-statistic': f_stat, 'p-value': p_val})

# Convert results to a DataFrame
anova_df = pd.DataFrame(anova_results)

# Display the ANOVA results
display(anova_df)

# Optionally, filter for significant genes
significant_genes = anova_df[anova_df['p-value'] < 0.05]
print("Significant Genes with p-value < 0.05:")
display(significant_genes)

# %%
from pybiomart import Dataset

# Connect to the Ensembl BioMart server
dataset = Dataset(name='hsapiens_gene_ensembl', host='http://www.ensembl.org')



# List all available attributes
attributes = dataset.attributes
print(attributes.head())  # This will show you the first few attributes

# List all available filters
filters = dataset.filters
print(filters.head())  # This will show you the first few filters

# Query gene names for specific Ensembl IDs
results = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'],
                        filters={'ensembl_gene_id': ["ENSG00000139618", "ENSG00000273279", "ENSG00000157764"]})

# Print the results
print(results)

# %%
# List all available attributes (first few)
attributes = dataset.attributes
print("Available attributes:")
for i, (key, value) in enumerate(attributes.items()):
    if i >= 5:  # Change this number to see more or fewer entries
        break
    print(f"{key}: {value}")

# List all available filters (first few)
filters = dataset.filters
print("\nAvailable filters:")
for i, (key, value) in enumerate(filters.items()):
    if i >= 5:  # Change this number to see more or fewer entries
        break
    print(f"{key}: {value}")


# Query gene names for specific Ensembl IDs
results = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'],
                        filters={'gene_id': ["ENSG00000139618", "ENSG00000273279", "ENSG00000157764"]})

# Print the results
print("Here come the results: ")
print(results)

results = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'],
                        filters={'gene_id': ["ENSG%"]})
print(results)

# %%
# Code Block 2

#ENSG00000258924

Dict_ensemble_gene_id = {
    Ras: "ENSG00000258924",
    Raf: ""
    Rafp: ""
}


# Check if gene ENSG00000258924 is present in the dataframe
gene_id = "ENSG00000258924"
gene_id_present = gene_id in df_mex_tpms["ENSEMBL_GENE_ID"].values
print(gene_id_present)

            


#["ENSG00000258924"]]

# %%
filename_acral_protein_NCN = "acral_protein_geomx_NCN_counts.csv"

df_protein_NCN = pd.read_csv (os.path.join(data_dir, filename_acral_protein_NCN))
display(df_protein_NCN)

# %%
col_names_tpms = df_mex_tpms.columns
print("The column names of the tpms dataframe are {}".format(col_names_tpms))

col_names_NCN = df_protein_NCN.columns
print("The column names of the protein_NCN dataframe are {}".format(col_names_NCN))
